# %%
import numpy as np
import matplotlib.pyplot as plt

d = []
v = []
ran = np.arange(0,1,.001)
for pi in ran:
    v.append(-np.log(pi))
    d.append(pi)


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Major ticks every 20, minor ticks every 5
x_major_ticks = np.arange(0, 1, .2)
x_minor_ticks = np.arange(0, 1, .1)

y_major_ticks = np.arange(0, 7, .5)
y_minor_ticks = np.arange(0, 7, .1)

ax.set_xticks(x_major_ticks)
ax.set_xticks(x_minor_ticks, minor=True)
ax.set_yticks(y_major_ticks)
ax.set_yticks(y_minor_ticks, minor=True)

ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)

ax.plot(d,v)
plt.xlabel("Probability of positive class")
plt.ylabel("Cross Entropy Loss")

plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11228\1217364176.py:8: RuntimeWarning: divide by zero encountered in log
#   v.append(-np.log(pi))
